# %%
import pandas as pd 
import matplotlib.pyplot as ps

# %%
df=pd.read_csv( r"C:\Users\Vikas\jupyter book\bais_utube_8.csv")

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # checking null values

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # For "house o Cards" ,what is a show id and who is the  director of this shows ?

# %%
df[df['Title']=="House of Cards"]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
df[df['Title'].isin(["House of Cards"])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # In which year the higest no of Tv Shows and Movies were release

# %%
df['year']=pd.to_datetime(df["Release_Date"])
# Out:
# C:\Users\Vikas\AppData\Local\Temp\ipykernel_15328\3621290852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year']=pd.to_datetime(df["Release_Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7787 entries, 0 to 7788
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
#  11  year          7777 non-null   datetime64[ns]
#  12  n_year        7777 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(11)
# memory usage: 1.1+ MB

# %%
df["year"].dt.year.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
df.groupby(df.Category).Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
df.groupby(df.Category).Category.count().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='Category'>

# %%
df["n_year"]=df["year"].dt.year
# Out:
# C:\Users\Vikas\AppData\Local\Temp\ipykernel_15328\2291170275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["n_year"]=df["year"].dt.year

# %% [markdown]
# # Shows all the movies tht were release in 2000 ?

# %%
df[(df["Category"]=="Movie")  &(df["year"]=="2000") ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year, n_year]
# Index: []

# %%
df[(df["Category"]=="Movie")  &(df["year"]=="2020") ]
# Out:
#      Show_Id Category                                              Title  \
# 4         s5    Movie                                                 21
# 163     s164    Movie                                 A Cinderella Story
# 433     s434    Movie  Alpha and Omega: The Legend of the Saw Tooth Cave
# 455     s456    Movie                                    American Beauty
# 588     s589    Movie                                   Arthur Christmas
# ...      ...      ...                                                ...
# 7560   s7559    Movie                                  What Lies Beneath
# 7625   s7624    Movie                                     Wild Wild West
# 7630   s7629    Movie                Willy Wonka & the Chocolate Factory
# 7683   s7682    Movie                                         Wyatt Earp
# 7707   s7706    Movie                                            Yes Man
#
#               Director                                               Cast  \
# ...

# %% [markdown]
# # show only the Title of Tv shows which were only relase in india

# %%
df.groupby(df.Country=="India")["Title","Category"].head(5)
# Out:
# C:\Users\Vikas\AppData\Local\Temp\ipykernel_15328\3857627331.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(df.Country=="India")["Title","Category"].head(5)
#                    Title Category
# 0                     3%  TV Show
# 1                  07:19    Movie
# 2                  23:59    Movie
# 3                      9    Movie
# 4                     21    Movie
# 8                    706    Movie
# 9                   1920    Movie
# 18                15-Aug    Movie
# 20  ​​Kuch Bheege Alfaaz    Movie
# 21          ​Goli Soda 2    Movie

# %%
df[(df["Country"]=="India") & (df["Category"]=="TV Show")]["Title"]
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# # show top 10 directors , who give the higest no of tv show and movies ?

# %%
df.groupby(df.Director).value_counts()
# Out:
# Director             Show_Id  Category  Title                  Cast                                                                                                                                                                                                                                           Country  Release_Date       Rating  Duration  Type                                                        Description                                                                                                                                               year        n_year
# ...

# %%
df["Director"].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %% [markdown]
# # show all the record wher category is movie an type is comedy or ocountry is uniited kingdom ?

# %%
df[(df["Category"]=="Movie") & (df["Type"]=="Comedies") | (df["Country"]=="United Kingdom")]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# # In how many movies shows tom Cruise is cast /

# %%
df.Cast.unique()
# Out:
# array(['João Miguel, Bianca Comparato, Michel Gomes, Rodolfo Valente, Vaneza Oliveira, Rafael Lozano, Viviane Porto, Mel Fronckowiak, Sergio Mamberti, Zezé Motta, Celso Frateschi',
#        'Demián Bichir, Héctor Bonilla, Oscar Serrano, Azalia Ortiz, Octavio Michel, Carmen Beato',
#        'Tedd Chan, Stella Chung, Henley Hii, Lawrence Koh, Tommy Kuan, Josh Lai, Mark Lee, Susan Leong, Benjamin Lim',
#        ...,
#        'Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy',
#        'Nasty C', 'Adriano Zumbo, Rachel Khoo'], dtype=object)

# %%
df[df["Cast"]=="Tom Cruise"]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year, n_year]
# Index: []

# %%
df[df["Cast"].str.contains("Tom Cruise")]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description       year  n_year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %%
df=df.dropna()

# %%
df[df["Cast"].str.contains("Tom Cruise")]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description       year  n_year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# # what r the different ratings define ?

# %%
df.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # how mants c show got T-4 recprd

# %%
df[(df["Rating"]=="R") & (df["Rating"]=="TV Show") & (df["n_year"]>2018)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year, n_year]
# Index: []

# %% [markdown]
# # what is maximum duration of tv/movies on /

# %%
df["Duration"].max()
# Out:
# '99 min'

# %% [markdown]
# # which indiviual country has higetno of tv show ?

# %%
df[df["Category"]=="TV Show"]["Country"].value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Spain                                                             7
# Taiwan                                                            6
# Turkey                                                            5
# India                                                             5
# Brazil                                                            4
# Canada                                                            3
# Thailand                                                          3
# Nigeria                                                           3
# France                                                            3
# China                                                             2
# ...

# %% [markdown]
# # how can we sort the datasett by year?

# %%
df.sort_values(by="year" ,ascending=False).head()
# Out:
#      Show_Id Category            Title                          Director  \
# 5060   s5060    Movie     Radium Girls  Lydia Dean Pilcher, Ginny Mohler
# 1673   s1674    Movie      Death of Me               Darren Lynn Bousman
# 205     s206    Movie  A Monster Calls                       J.A. Bayona
# 6977   s6976    Movie     The Vanished                   Peter Facinelli
# 1832   s1833    Movie       Double Dad                      Cris D'Amato
#
#                                                    Cast  \
# 5060  Joey King, Abby Quinn, Cara Seymour, Scott She...
# 1673  Maggie Q, Luke Hemsworth, Alex Essoe, Ingkarat...
# 205   Lewis MacDougall, Sigourney Weaver, Felicity J...
# 6977  Thomas Jane, Anne Heche, Jason Patric, John D....
# 1832  Maisa Silva, Eduardo Moscovis, Marcelo Médici,...
#
#                                    Country      Release_Date Rating Duration  \
# 5060                         United States  January 16, 2021  TV-14  103 min
# ...

# %% [markdown]
# # find all instance where :
# # category is movie and type is drama
# # category is tv show and type is kides

# %%
df[(df["Category"]=="Movie") & (df["Type"].str.contains("Dramas")) | (df["Category"]=="TV Show") & (df["Type"].str.contains("ids' TV"))]
# Out:
#      Show_Id Category     Title           Director  \
# 1         s2    Movie     07:19  Jorge Michel Grau
# 4         s5    Movie        21     Robert Luketic
# 7         s8    Movie       187     Kevin Reynolds
# 10       s11    Movie      1922       Zak Hilditch
# 15       s16    Movie    Oct-01     Kunle Afolayan
# ...      ...      ...       ...                ...
# 7776   s7775    Movie    Zodiac      David Fincher
# 7778   s7777    Movie  Zokkomon   Satyajit Bhatkal
# 7782   s7781    Movie       Zoo       Shlok Sharma
# 7784   s7783    Movie      Zozo        Josef Fares
# 7785   s7784    Movie    Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 10    Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# 15    Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...
# ...

# %%
# Out:
# array(['Dramas, International Movies',
#        'Horror Movies, International Movies',
#        'Action & Adventure, Independent Movies, Sci-Fi & Fantasy',
#        'Dramas', 'International TV Shows, TV Dramas, TV Mysteries',
#        'Horror Movies, International Movies, Thrillers',
#        'Dramas, Thrillers',
#        'Documentaries, International Movies, Sports Movies',
#        'Independent Movies, Sci-Fi & Fantasy, Thrillers',
#        'Dramas, International Movies, Thrillers',
#        'Comedies, Dramas, Independent Movies',
#        'Dramas, Independent Movies, International Movies',
#        'Action & Adventure, Dramas, International Movies',
#        'Documentaries, International Movies',
#        'Dramas, International Movies, Romantic Movies', 'Comedies',
#        'Comedies, Romantic Movies',
#        'Comedies, Dramas, International Movies',
#        'Comedies, International Movies',
#        'Action & Adventure, Sci-Fi & Fantasy', 'Dramas, Romantic Movies',
# ...
